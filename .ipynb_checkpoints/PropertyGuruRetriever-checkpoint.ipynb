# %%
from selenium import webdriver 
from selenium.webdriver.firefox.options import Options
import os
import re
import time
from selenium.webdriver.common.action_chains import ActionChains
from selenium.common.exceptions import NoSuchElementException

# %%
def urlify(s):
    
    # Remove all non-word characters (everything except numbers and letters)
    # s = re.sub(r"[^\w\s]", '', s)

    # Replace all runs of whitespace with a single dash
    s = re.sub(r"\s+", '+', s)

    return s

# %%
def StartSeleniumWindows(url):
    options = Options()
    options.headless = True
    assert options.headless
    options.binary_location = r"C:\Users\yeewl\AppData\Local\Mozilla Firefox\firefox.exe"
    #options.binary_location = r"C:\Program Files\Mozilla Firefox\firefox.exe"
    driver = webdriver.Firefox(executable_path=".\geckodriver.exe",options=options)
    location = "Jurong West Street 61"
    #driver.get("https://www.propertyguru.com.sg/property-for-sale?market=residential&property_type_code%5B%5D=1R&property_type_code%5B%5D=2A&property_type_code%5B%5D=2I&property_type_code%5B%5D=2S&property_type_code%5B%5D=3A&property_type_code%5B%5D=3NG&property_type_code%5B%5D=3Am&property_type_code%5B%5D=3NGm&property_type_code%5B%5D=3I&property_type_code%5B%5D=3Im&property_type_code%5B%5D=3S&property_type_code%5B%5D=3STD&property_type_code%5B%5D=4A&property_type_code%5B%5D=4NG&property_type_code%5B%5D=4S&property_type_code%5B%5D=4I&property_type_code%5B%5D=4STD&property_type_code%5B%5D=5A&property_type_code%5B%5D=5I&property_type_code%5B%5D=5S&property_type_code%5B%5D=6J&property_type_code%5B%5D=EA&property_type_code%5B%5D=EM&property_type_code%5B%5D=MG&property_type_code%5B%5D=TE&property_type=H&freetext=" + format(urlify(location)))
    driver.get(url)
    return driver

# %%
def StartSeleniumUbuntu():
    path = os.path.join(os.path.expanduser('~'), 'irs', 'HDBResalePriceRecommender', 'geckodriver-v0.29.0', 'geckodriver')
    options = Options()
    options.headless = True
    assert options.headless
    driver = webdriver.Firefox(executable_path=path, options=options)
    driver.get("https://www.propertyguru.com.sg/property-for-sale?market=residential&property_type_code%5B%5D=1R&property_type_code%5B%5D=2A&property_type_code%5B%5D=2I&property_type_code%5B%5D=2S&property_type_code%5B%5D=3A&property_type_code%5B%5D=3NG&property_type_code%5B%5D=3Am&property_type_code%5B%5D=3NGm&property_type_code%5B%5D=3I&property_type_code%5B%5D=3Im&property_type_code%5B%5D=3S&property_type_code%5B%5D=3STD&property_type_code%5B%5D=4A&property_type_code%5B%5D=4NG&property_type_code%5B%5D=4S&property_type_code%5B%5D=4I&property_type_code%5B%5D=4STD&property_type_code%5B%5D=5A&property_type_code%5B%5D=5I&property_type_code%5B%5D=5S&property_type_code%5B%5D=6J&property_type_code%5B%5D=EA&property_type_code%5B%5D=EM&property_type_code%5B%5D=MG&property_type_code%5B%5D=TE&property_type=H&freetext={1}".format(location))
    return driver

# %%
# Pending:
# - take block number or postal as search
# - take MRT as search

# %%
driver = StartSeleniumWindows()
elem = driver.find_elements_by_class_name("pagination")
#print(elem[0].text)
lastpage = int(elem[0].text.splitlines()[-2]) # usually «\n1\n2\n...\n441\n», hence get 2nd last element
print(lastpage)
# Out:
# 441

# %%
results = []
residx = 1

tic = time.perf_counter()
for i in range(1,10):
    pageURL = "https://www.propertyguru.com.sg/property-for-sale/{0}?property_type_code%5B0%5D=1R&property_type_code%5B1%5D=2A&property_type_code%5B2%5D=2I&property_type_code%5B3%5D=2S&property_type_code%5B4%5D=3A&property_type_code%5B5%5D=3NG&property_type_code%5B6%5D=3Am&property_type_code%5B7%5D=3NGm&property_type_code%5B8%5D=3I&property_type_code%5B9%5D=3Im&property_type_code%5B10%5D=3S&property_type_code%5B11%5D=3STD&property_type_code%5B12%5D=4A&property_type_code%5B13%5D=4NG&property_type_code%5B14%5D=4S&property_type_code%5B15%5D=4I&property_type_code%5B16%5D=4STD&property_type_code%5B17%5D=5A&property_type_code%5B18%5D=5I&property_type_code%5B19%5D=5S&property_type_code%5B20%5D=6J&property_type_code%5B21%5D=EA&property_type_code%5B22%5D=EM&property_type_code%5B23%5D=MG&property_type_code%5B24%5D=TE&property_type=H".format(str(i))
    print(pageURL)
    driver = StartSeleniumWindows(pageURL)
    time.sleep(2)
    listings = driver.find_elements_by_class_name("listing-location")
    prices = driver.find_elements_by_css_selector("span.price")
    for i, (l, p) in enumerate(zip(listings, prices)):
        residx = residx + 1
        print("Listing {0}: {1} at {2}".format(str(residx), l.text, p.text))
        results.append([l.text, p.text])
    time.sleep(2)
    driver.quit()
    print(f"time {(time.perf_counter() - tic)/60} minutes")
# Out:
# https://www.propertyguru.com.sg/property-for-sale/1?property_type_code%5B0%5D=1R&property_type_code%5B1%5D=2A&property_type_code%5B2%5D=2I&property_type_code%5B3%5D=2S&property_type_code%5B4%5D=3A&property_type_code%5B5%5D=3NG&property_type_code%5B6%5D=3Am&property_type_code%5B7%5D=3NGm&property_type_code%5B8%5D=3I&property_type_code%5B9%5D=3Im&property_type_code%5B10%5D=3S&property_type_code%5B11%5D=3STD&property_type_code%5B12%5D=4A&property_type_code%5B13%5D=4NG&property_type_code%5B14%5D=4S&property_type_code%5B15%5D=4I&property_type_code%5B16%5D=4STD&property_type_code%5B17%5D=5A&property_type_code%5B18%5D=5I&property_type_code%5B19%5D=5S&property_type_code%5B20%5D=6J&property_type_code%5B21%5D=EA&property_type_code%5B22%5D=EM&property_type_code%5B23%5D=MG&property_type_code%5B24%5D=TE&property_type=H
# Listing 2: 374 Hougang Street 31 at 1,088,000
# Listing 3: 51 Strathmore Avenue at 729,000
# Listing 4: 612B Punggol Drive at 488,000
# Listing 5: 471A Fernvale Street at 440,000
# Listing 6: 315A Punggol Way at 570,000
# Listing 7: 217C Sumang Walk at 528,000
# Listing 8: 4B Boon Tiong Road at 880,000
# Listing 9: 6 Boon Keng Road at 850,000
# Listing 10: 194A Bukit Batok West Avenue 6 at 670,000
# Listing 11: 669A Edgefield Plains at 599,000
# Listing 12: 716 Ang Mo Kio Avenue 6 at 650,000
# Listing 13: 310B Punggol Walk at 699,999
# Listing 14: 310B Punggol Walk at 550,000
# Listing 15: 99 Commonwealth Crescent at 360,000
# Listing 16: 473A Upper Serangoon Crescent at 680,000
# Listing 17: 43 Chai Chee Street at 438,000
# Listing 18: 540 Pasir Ris Street 51 at 718,000
# Listing 19: 106 Simei Street 1 at 588,000
# Listing 20: 226 Bishan Street 23 at 649,950
# Listing 21: 310B Anchorvale Road at 480,000
# time 0.26299973166666746 minutes
# https://www.propertyguru.com.sg/property-for-sale/2?property_type_code%5B0%5D=1R&property_type_code%5B1%5D=2A&property_type_code%5B2%5D=2I&property_type_code%5B3%5D=2S&property_type_code%5B4%5D=3A&property_type_code%5B5%5D=3NG&property_type_code%5B6%5D=3Am&property_type_code%5B7%5D=3NGm&property_type_code%5B8%5D=3I&property_type_code%5B9%5D=3Im&property_type_code%5B10%5D=3S&property_type_code%5B11%5D=3STD&property_type_code%5B12%5D=4A&property_type_code%5B13%5D=4NG&property_type_code%5B14%5D=4S&property_type_code%5B15%5D=4I&property_type_code%5B16%5D=4STD&property_type_code%5B17%5D=5A&property_type_code%5B18%5D=5I&property_type_code%5B19%5D=5S&property_type_code%5B20%5D=6J&property_type_code%5B21%5D=EA&property_type_code%5B22%5D=EM&property_type_code%5B23%5D=MG&property_type_code%5B24%5D=TE&property_type=H
# Listing 22: 87 Dawson Road at 838,000
# Listing 23: 34 Whampoa West at 335,000
# Listing 24: 273A Punggol Place at 469,000
# Listing 25: 99 Commonwealth Crescent at 360,000
# Listing 26: 514 Bukit Batok Street 52 at 495,000
# Listing 27: 152 Lorong 2 Toa Payoh at 860,000
# Listing 28: 271C Punggol Walk at 780,000
# Listing 29: 308A Punggol Walk at 765,000
# Listing 30: 93 Dawson Road at 838,000
# Listing 31: 308C Punggol Walk at 560,000
# Listing 32: 3 Holland Close at 798,000
# Listing 33: 138 Marsiling Road at 768,000
# Listing 34: 401 Serangoon Avenue 1 at 600,000
# Listing 35: 86 Dawson Road at 880,000
# Listing 36: 310A Punggol Walk at 580,000
# Listing 37: 88 Dawson Road at 868,000
# Listing 38: 88 Dawson Road at 799,999
# Listing 39: 1 Queen's Road at 950,000
# Listing 40: 318B Yishun Avenue 9 at 590,000
# Listing 41: 283 Yishun Avenue 6 at 420,000
# time 0.5160688666666677 minutes
# https://www.propertyguru.com.sg/property-for-sale/3?property_type_code%5B0%5D=1R&property_type_code%5B1%5D=2A&property_type_code%5B2%5D=2I&property_type_code%5B3%5D=2S&property_type_code%5B4%5D=3A&property_type_code%5B5%5D=3NG&property_type_code%5B6%5D=3Am&property_type_code%5B7%5D=3NGm&property_type_code%5B8%5D=3I&property_type_code%5B9%5D=3Im&property_type_code%5B10%5D=3S&property_type_code%5B11%5D=3STD&property_type_code%5B12%5D=4A&property_type_code%5B13%5D=4NG&property_type_code%5B14%5D=4S&property_type_code%5B15%5D=4I&property_type_code%5B16%5D=4STD&property_type_code%5B17%5D=5A&property_type_code%5B18%5D=5I&property_type_code%5B19%5D=5S&property_type_code%5B20%5D=6J&property_type_code%5B21%5D=EA&property_type_code%5B22%5D=EM&property_type_code%5B23%5D=MG&property_type_code%5B24%5D=TE&property_type=H
# Listing 42: 283 Yishun Avenue 6 at 420,000
# Listing 43: 293C Compassvale Crescent at 495,000
# Listing 44: 613A Punggol Drive at 500,000
# Listing 45: 293A Compassvale Crescent at 518,000
# Listing 46: 308 Shunfu Road at 438,000
# Listing 47: 347B Yishun Avenue 11 at 648,888
# Listing 48: 311C Clementi Avenue 4 at 1,128,000
# Listing 49: 308B Punggol Walk at 528,888
# Listing 50: 678B Punggol Drive at 578,000
# Listing 51: 194A Bukit Batok West Avenue 6 at 670,000
# Listing 52: 579 Pasir Ris Street 53 at 778,000
# Listing 53: 8C Upper Boon Keng Road at 888,888
# Listing 54: 217C Sumang Walk at 650,000
# Listing 55: 43 Marine Crescent at 770,000
# Listing 56: 334B Anchorvale Crescent at 535,000
# Listing 57: 23 Eunos Crescent at 575,000
# Listing 58: 547A Segar Road at 600,000
# Listing 59: 310 Shunfu Road at 728,000
# Listing 60: 130 Geylang East Avenue 1 at 830,000
# Listing 61: 805A Keat Hong Close at 470,000
# time 0.773479338333334 minutes
# https://www.propertyguru.com.sg/property-for-sale/4?property_type_code%5B0%5D=1R&property_type_code%5B1%5D=2A&property_type_code%5B2%5D=2I&property_type_code%5B3%5D=2S&property_type_code%5B4%5D=3A&property_type_code%5B5%5D=3NG&property_type_code%5B6%5D=3Am&property_type_code%5B7%5D=3NGm&property_type_code%5B8%5D=3I&property_type_code%5B9%5D=3Im&property_type_code%5B10%5D=3S&property_type_code%5B11%5D=3STD&property_type_code%5B12%5D=4A&property_type_code%5B13%5D=4NG&property_type_code%5B14%5D=4S&property_type_code%5B15%5D=4I&property_type_code%5B16%5D=4STD&property_type_code%5B17%5D=5A&property_type_code%5B18%5D=5I&property_type_code%5B19%5D=5S&property_type_code%5B20%5D=6J&property_type_code%5B21%5D=EA&property_type_code%5B22%5D=EM&property_type_code%5B23%5D=MG&property_type_code%5B24%5D=TE&property_type=H
# Listing 62: 88 Dawson Road at 850,000
# Listing 63: 937 Hougang Street 92 at 550,000
# Listing 64: 61A Strathmore Avenue at 550,000
# Listing 65: 217A Sumang Walk at 600,000
# Listing 66: 272A Punggol Walk at 498,000
# Listing 67: 208A Clementi Avenue 6 at 789,000
# Listing 68: 256D Sumang Walk at 478,000
# Listing 69: 475C Upper Serangoon Crescent at 665,000
# Listing 70: 314B Punggol Way at 520,000
# Listing 71: 278C Compassvale Bow at 628,000
# Listing 72: 473A Upper Serangoon Crescent at 758,000
# Listing 73: 38 Beo Crescent at 370,000
# Listing 74: 310A Punggol Walk at 515,000
# Listing 75: 310A Punggol Walk at 750,000
# Listing 76: 889 Tampines Street 81 at 788,000
# Listing 77: 31 Bedok South Avenue 2 at 658,000
# Listing 78: 90A Telok Blangah Street 31 at 680,000
# Listing 79: 788E Woodlands Crescent at 688,000
# Listing 80: 443 Ang Mo Kio Avenue 10 at 430,000
# Listing 81: 336C Anchorvale Crescent at 558,000
# time 1.022794163333333 minutes
# https://www.propertyguru.com.sg/property-for-sale/5?property_type_code%5B0%5D=1R&property_type_code%5B1%5D=2A&property_type_code%5B2%5D=2I&property_type_code%5B3%5D=2S&property_type_code%5B4%5D=3A&property_type_code%5B5%5D=3NG&property_type_code%5B6%5D=3Am&property_type_code%5B7%5D=3NGm&property_type_code%5B8%5D=3I&property_type_code%5B9%5D=3Im&property_type_code%5B10%5D=3S&property_type_code%5B11%5D=3STD&property_type_code%5B12%5D=4A&property_type_code%5B13%5D=4NG&property_type_code%5B14%5D=4S&property_type_code%5B15%5D=4I&property_type_code%5B16%5D=4STD&property_type_code%5B17%5D=5A&property_type_code%5B18%5D=5I&property_type_code%5B19%5D=5S&property_type_code%5B20%5D=6J&property_type_code%5B21%5D=EA&property_type_code%5B22%5D=EM&property_type_code%5B23%5D=MG&property_type_code%5B24%5D=TE&property_type=H
# Listing 82: 309A Ang Mo Kio Street 31 at 870,000
# Listing 83: 258D Compassvale Road at 530,000
# Listing 84: 6 Holland Close at 419,000
# Listing 85: 243 Serangoon Avenue 2 at 628,000
# Listing 86: 127A Kim Tian Road at 850,000
# Listing 87: 91 Dawson Road at 882,000
# Listing 88: 87 Dawson Road at 780,000
# Listing 89: 86 Dawson Road at 798,000
# Listing 90: 21 Holland Drive at 798,000
# Listing 91: 174B Edgedale Plains at 420,000
# Listing 92: 2 Tanjong Pagar Plaza at 470,000
# Listing 93: 677C Punggol Drive at 638,000
# Listing 94: 670B Edgefield Plains at 465,000
# Listing 95: 274C Punggol Place at 468,000
# Listing 96: 453B Fernvale Road at 520,000
# Listing 97: 294A Compassvale Crescent at 498,000
# Listing 98: 334A Anchorvale Crescent at 475,000
# Listing 99: 519D Tampines Central 8 at 859,000
# Listing 100: 138A Yuan Ching Road at 650,000
# Listing 101: 17B Circuit Road at 800,000
# time 1.2811957799999998 minutes
# https://www.propertyguru.com.sg/property-for-sale/6?property_type_code%5B0%5D=1R&property_type_code%5B1%5D=2A&property_type_code%5B2%5D=2I&property_type_code%5B3%5D=2S&property_type_code%5B4%5D=3A&property_type_code%5B5%5D=3NG&property_type_code%5B6%5D=3Am&property_type_code%5B7%5D=3NGm&property_type_code%5B8%5D=3I&property_type_code%5B9%5D=3Im&property_type_code%5B10%5D=3S&property_type_code%5B11%5D=3STD&property_type_code%5B12%5D=4A&property_type_code%5B13%5D=4NG&property_type_code%5B14%5D=4S&property_type_code%5B15%5D=4I&property_type_code%5B16%5D=4STD&property_type_code%5B17%5D=5A&property_type_code%5B18%5D=5I&property_type_code%5B19%5D=5S&property_type_code%5B20%5D=6J&property_type_code%5B21%5D=EA&property_type_code%5B22%5D=EM&property_type_code%5B23%5D=MG&property_type_code%5B24%5D=TE&property_type=H
# Listing 102: 260C Punggol Way at 510,000
# Listing 103: 286A Compassvale Crescent at 650,000
# Listing 104: 473D Upper Serangoon Crescent at 680,000
# Listing 105: 156 Tampines Street 12 at 970,000
# Listing 106: 245 Hougang Street 22 at 520,000
# Listing 107: 258A Punggol Field at 520,000
# Listing 108: 27 Ghim Moh Link at 888,000
# Listing 109: 1 Cantonment Road at 1,238,888
# Listing 110: 665A Punggol Drive at 639,000
# Listing 111: 18 Jalan Tenteram at 678,000
# Listing 112: 302A Anchorvale Link at 518,000
# Listing 113: 601D Punggol Central at 485,000
# Listing 114: 48A Strathmore Avenue at 798,000
# Listing 115: 297A Compassvale Street at 648,000
# Listing 116: 1F Cantonment Road at 1,050,000
# Listing 117: 18D Holland Drive at 950,000
# Listing 118: 503 Jelapang Road at 725,000
# Listing 119: 666A Punggol Drive at 635,000
# Listing 120: 312C Clementi Avenue 4 at 900,000
# Listing 121: 652 Punggol Central at 550,000
# time 1.5368671283333337 minutes
# https://www.propertyguru.com.sg/property-for-sale/7?property_type_code%5B0%5D=1R&property_type_code%5B1%5D=2A&property_type_code%5B2%5D=2I&property_type_code%5B3%5D=2S&property_type_code%5B4%5D=3A&property_type_code%5B5%5D=3NG&property_type_code%5B6%5D=3Am&property_type_code%5B7%5D=3NGm&property_type_code%5B8%5D=3I&property_type_code%5B9%5D=3Im&property_type_code%5B10%5D=3S&property_type_code%5B11%5D=3STD&property_type_code%5B12%5D=4A&property_type_code%5B13%5D=4NG&property_type_code%5B14%5D=4S&property_type_code%5B15%5D=4I&property_type_code%5B16%5D=4STD&property_type_code%5B17%5D=5A&property_type_code%5B18%5D=5I&property_type_code%5B19%5D=5S&property_type_code%5B20%5D=6J&property_type_code%5B21%5D=EA&property_type_code%5B22%5D=EM&property_type_code%5B23%5D=MG&property_type_code%5B24%5D=TE&property_type=H
# Listing 122: 472A Fernvale Street at 608,888
# Listing 123: 314 Hougang Avenue 5 at 420,000
# Listing 124: 72 Bedok South Avenue 3 at 568,000
# Listing 125: 232A Serangoon Avenue 2 at 1,100,000
# Listing 126: 86 Dawson Road at 1,100,000
# Listing 127: 310B Punggol Walk at 520,000
# Listing 128: cantonment road at 899,888
# Listing 129: 86 Dawson Road at 880,000
# Listing 130: 710 Pasir Ris Street 72 at 658,000
# Listing 131: 245 Tampines Street 21 at 770,000
# Listing 132: 265B Punggol Way at 545,000
# Listing 133: 217B Sumang Walk at 630,000
# Listing 134: 288C Punggol Place at 508,000
# Listing 135: 90 Tanglin Halt Road at 840,000
# Listing 136: 767 Bedok Reservoir View at 608,888
# Listing 137: 90 Tanglin Halt Road at 878,000
# Listing 138: 271C Punggol Walk at 488,000
# Listing 139: 215A Compassvale Drive at 450,000
# Listing 140: 217B Sumang Walk at 525,000
# Listing 141: 2 Marine Terrace at 908,000
# time 1.7932032516666672 minutes
# https://www.propertyguru.com.sg/property-for-sale/8?property_type_code%5B0%5D=1R&property_type_code%5B1%5D=2A&property_type_code%5B2%5D=2I&property_type_code%5B3%5D=2S&property_type_code%5B4%5D=3A&property_type_code%5B5%5D=3NG&property_type_code%5B6%5D=3Am&property_type_code%5B7%5D=3NGm&property_type_code%5B8%5D=3I&property_type_code%5B9%5D=3Im&property_type_code%5B10%5D=3S&property_type_code%5B11%5D=3STD&property_type_code%5B12%5D=4A&property_type_code%5B13%5D=4NG&property_type_code%5B14%5D=4S&property_type_code%5B15%5D=4I&property_type_code%5B16%5D=4STD&property_type_code%5B17%5D=5A&property_type_code%5B18%5D=5I&property_type_code%5B19%5D=5S&property_type_code%5B20%5D=6J&property_type_code%5B21%5D=EA&property_type_code%5B22%5D=EM&property_type_code%5B23%5D=MG&property_type_code%5B24%5D=TE&property_type=H
# Listing 142: 86 Dawson Road at 880,000
# Listing 143: 661C Edgedale Plains at 490,000
# Listing 144: 91 Dawson Road at 882,000
# Listing 145: 311C Clementi Avenue 4 at 768,888
# Listing 146: 365B Upper Serangoon Road at 550,000
# Listing 147: 684B Choa Chu Kang Crescent at 460,000
# Listing 148: 1E Cantonment Road at 928,888
# Listing 149: 876 Tampines Street 84 at 518,000
# Listing 150: 142 Bishan Street 12 at 880,000
# Listing 151: 79E Toa Payoh Central at 899,999
# Listing 152: 217B Compassvale Drive at 448,000
# Listing 153: 1 Cantonment Road at 1,288,000
# Listing 154: 173A Punggol Field at 489,000
# Listing 155: 564 Pasir Ris Street 51 at 580,000
# Listing 156: 88 Dawson Road at 868,600
# Listing 157: 678A Punggol Drive at 510,000
# Listing 158: 288B Punggol Place at 493,888
# Listing 159: 9B Boon Tiong Road at 988,000
# Listing 160: 232A Serangoon Avenue 2 at 950,000
# Listing 161: 501B Yishun Street 51 at 650,000
# time 2.0462011966666673 minutes
# https://www.propertyguru.com.sg/property-for-sale/9?property_type_code%5B0%5D=1R&property_type_code%5B1%5D=2A&property_type_code%5B2%5D=2I&property_type_code%5B3%5D=2S&property_type_code%5B4%5D=3A&property_type_code%5B5%5D=3NG&property_type_code%5B6%5D=3Am&property_type_code%5B7%5D=3NGm&property_type_code%5B8%5D=3I&property_type_code%5B9%5D=3Im&property_type_code%5B10%5D=3S&property_type_code%5B11%5D=3STD&property_type_code%5B12%5D=4A&property_type_code%5B13%5D=4NG&property_type_code%5B14%5D=4S&property_type_code%5B15%5D=4I&property_type_code%5B16%5D=4STD&property_type_code%5B17%5D=5A&property_type_code%5B18%5D=5I&property_type_code%5B19%5D=5S&property_type_code%5B20%5D=6J&property_type_code%5B21%5D=EA&property_type_code%5B22%5D=EM&property_type_code%5B23%5D=MG&property_type_code%5B24%5D=TE&property_type=H
# Listing 162: 289D Punggol Place at 550,000
# Listing 163: 475 Segar Road at 598,000
# Listing 164: 678B Punggol Drive at 538,000
# Listing 165: 504D Yishun Street 51 at 440,000
# Listing 166: 1 Tanjong Pagar Plaza at 518,000
# Listing 167: 635 Hougang Avenue 8 at 465,000
# Listing 168: 430A Yishun Avenue 11 at 450,000
# Listing 169: 1F Cantonment Road at 1,050,000
# Listing 170: 1D Cantonment Road at 1,280,000
# Listing 171: 209 Yishun Street 21 at 560,000
# Listing 172: 58 Telok Blangah Heights at 490,000
# Listing 173: 38D Bendemeer Road at 720,000
# Listing 174: 661C Edgedale Plains at 525,000
# Listing 175: 281B Sengkang East Avenue at 588,000
# Listing 176: 87 Telok Blangah Heights at 620,000
# Listing 177: 278A Compassvale Bow at 728,000
# Listing 178: 335A Anchorvale Crescent at 650,000
# Listing 179: 215A Compassvale Drive at 450,000
# Listing 180: 158B Rivervale Crescent at 460,000
# Listing 181: 414A Fernvale Link at 508,000
# time 2.2965637883333327 minutes
